# %% [markdown]
# # Netkeiba Race Result Scraping

# %%
from bs4 import BeautifulSoup
import requests
import urllib.request
import pandas as pd
import numpy as np

# %%
race_id='202306050601'

# %%
url = 'https://race.netkeiba.com/race/result.html?race_id='+race_id

source = urllib.request.urlopen(url)
soup = BeautifulSoup(source,'lxml')

main_table=soup('table', class_="RaceTable01 RaceCommon_Table ResultRefund Table_Show_All")[0]

head = []
for i in range(len(main_table.find_all('th'))):
    head.append(main_table.find_all('th')[i].get_text())

data=[]
for d in range(len(main_table.find_all('td'))):
    data.append(main_table.find_all('td')[d].get_text())

n=len(main_table.find_all('th'))
data = [data[i:i+n] for i in range(0,len(data),n)]

data_array=np.array(data)

dataset= pd.DataFrame(data_array,columns=head)

for col in dataset.columns:
    for i in range(len(dataset)):
        dataset.loc[i,col]=dataset.loc[i,col].replace('\n','').replace('\t','')

# %%
display(dataset)
dataset.to_csv(race_id+'.csv', index=False)
# Out:
#     着順  枠  馬番      \n馬名\n  性齢    斤量      騎手     タイム     着差  人気  単勝オッズ   後3F  \
# 0    1  7  14        セリエル  牝2  55.0     大野   1:12.8          1    1.7  38.7
# 1    2  8  16      サノノリッチ  牝2  55.0      黛   1:13.3      3  12  159.9  38.5
# 2    3  6  12     マリノルージュ  牝2  54.0   ☆横山琉   1:13.3     クビ   7   21.9  38.9
# 3    4  4   7       プラビータ  牝2  54.0    ☆永野   1:13.5  1.1/4   5   17.5  39.4
# 4    5  5  10    レヴィテーション  牝2  51.0   ★小林美   1:13.8  1.1/2   6   17.9  38.5
# 5    6  3   6       ヨッコサン  牝2  55.0    柴田大   1:13.9    1/2   4   10.7  39.5
# 6    7  8  15      ミスヨシゼン  牝2  55.0    内田博   1:14.1      1  11  114.5  38.8
# 7    8  4   8      ヒナボンボン  牝2  52.0    ▲佐藤   1:14.2    3/4  14  244.8  38.7
# 8    9  6  11      ハーツケリー  牝2  55.0     丹内   1:14.2     ハナ   9   46.2  38.8
# 9   10  3   5      ブランシール  牝2  55.0    北村宏   1:14.3     クビ   3    7.6  38.7
# 10  11  5   9     ユキノフルマチ  牝2  54.0     ☆原   1:14.3     クビ  10  102.7  39.3
# 11  12  7  13      ジーズデイズ  牝2  55.0    木幡巧   1:14.4     クビ  15  482.6  39.2
# 12  13  2   3      サンリコリス  牝2  55.0     岩部   1:14.8  2.1/2   8   40.3  40.3
# 13  14  2   4     グラスファイン  牝2  53.0   ◇藤田菜   1:15.6      5  13  207.7  41.2
# 14  15  1   2   レガシーオブエリザ  牝2  55.0    戸崎圭   1:15.9  1.3/4   2    7.3  41.8
# 15  16  1   1        シャボン  牝2  55.0     杉原   1:16.9      6  16  563.8  40.1
#
#    コーナー通過順     厩舎    馬体重(増減)
# 0      2-1   美浦杉浦    456(-2)
# 1      8-6   美浦中野    416(-8)
# 2      4-4   美浦田島    458(+2)
# 3      2-2   美浦矢野   494(+12)
# 4    11-10   美浦中川     436(0)
# 5      4-4   美浦粕谷    498(+6)
# 6    11-12   美浦古賀    466(+6)
# 7    14-12  美浦小手川   490(-18)
# 8    11-12   美浦菊川    470(-4)
# 9    14-12   美浦稲垣    452(+4)
# 10     9-9   美浦矢野    478(+4)
# 11   10-10   美浦伊坂   454(+10)
# 12     4-6   美浦萱野    442(-8)
# 13     4-6   美浦佐藤    440(-4)
# 14     1-2   美浦青木    432(+2)
# 15   16-16   美浦南田   462(-18)
